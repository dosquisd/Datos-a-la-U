# %%
import pandas as pd 
import requests
import re
from unicodedata import normalize
from IPython.display import clear_output
from datetime import date, datetime


def remove_tildes(string: str) -> str:
    string = re.sub(
        r"([^n\u0300-\u036f]|n(?!\u0303(?![\u0300-\u036f])))[\u0300-\u036f]+", r"\1", 
        normalize("NFD", string), 0, re.I
    )
    string = normalize("NFC", string)
    return string

# %%
data1 = pd.read_csv(f'./raw/Procesos_en_Casas_de_Justicia_20241103.csv', engine='python')
data1
# Out:
#          IdSolicitud                                         NomEntidad  \
# 0             481137  UNIVERSIDAD  FACULTAD DE DERECHO  CONSULTORIOJ...
# 1            3930874  UNIVERSIDAD  FACULTAD DE DERECHO  CONSULTORIOJ...
# 2             414466  UNIVERSIDAD  FACULTAD DE DERECHO  CONSULTORIOJ...
# 3             441614  UNIVERSIDAD  FACULTAD DE DERECHO  CONSULTORIOJ...
# 4              39309  UNIVERSIDAD  FACULTAD DE DERECHO  CONSULTORIOJ...
# ...              ...                                                ...
# 3737187      6998858                            Conciliación en Equidad
# 3737188      6998861                            Conciliación en Equidad
# 3737189      6998863                            Conciliación en Equidad
# 3737190      6998867                            Conciliación en Equidad
# 3737191      6998868                            Conciliación en Equidad
#
#                       NomCasaJusticia               FechaSolicitud
# 0             Casa de Justicia Cajicá                   10/21/2019
# 1             Casa de Justicia Cajicá      2019-05-08T00:00:00.000
# 2             Casa de Justicia Cajicá                   09/16/2019
# 3             Casa de Justicia Cajicá                   09/30/2019
# 4             Casa de Justicia Cajicá      2019-05-08T00:00:00.000
# ...                               ...                          ...
# 3737187  Casa de Justicia Santa Marta  2024-09-30 18:32:12.7903092
# 3737188  Casa de Justicia Santa Marta  2024-09-30 18:38:10.1276910
# 3737189  Casa de Justicia Santa Marta  2024-09-30 18:59:42.8782731
# 3737190  Casa de Justicia Santa Marta  2024-09-30 20:03:26.6302227
# 3737191  Casa de Justicia Santa Marta  2024-09-30 20:06:36.7694749
#
# [3737192 rows x 4 columns]

# %%
data1.isna().sum()
# Out:
# IdSolicitud           0
# NomEntidad         1334
# NomCasaJusticia       0
# FechaSolicitud        0
# dtype: int64

# %%
data2 = pd.read_csv(f"./processed/directorio_casas_de_justicia*.csv")
data2
# Out:
#         DEPARTAMENTO   MUNICIPIO                  CASA DE JUSTICIA
# 0           AMAZONAS     LETICIA          CASA DE JUSTICIA LETICIA
# 1          ANTIOQUIA      AMALFI           CASA DE JUSTICIA AMALFI
# 2          ANTIOQUIA       ANORI            CASA DE JUSTICIA ANORI
# 3          ANTIOQUIA    APARTADO         CASA DE JUSTICIA APARTADO
# 4          ANTIOQUIA       BELLO            CASA DE JUSTICIA BELLO
# ..               ...         ...                               ...
# 153           BOGOTA      BOGOTA   CASA DE JUSTICIA BOGOTA USAQUEN
# 154           BOGOTA      BOGOTA  CASA DE JUSTICIA BOGOTA CALLE 45
# 155           BOGOTA      BOGOTA  CASA DE JUSTICIA BOGOTA ENGATIVA
# 156       SAN ANDRES  SAN ANDRES       CASA DE JUSTICIA SAN ANDRES
# 157  VALLE DEL CAUCA     FLORIDA          CASA DE JUSTICIA FLORIDA
#
# [158 rows x 3 columns]

# %% [markdown]
# ## Include longitude and latitude, and information about municipality and department

# %%
data1["NomCasaJusticia"] = data1["NomCasaJusticia"].apply(remove_tildes)
data1["NomCasaJusticia"] = data1["NomCasaJusticia"].apply(str.upper)
data1
# Out:
#          IdSolicitud                                         NomEntidad  \
# 0             481137  UNIVERSIDAD  FACULTAD DE DERECHO  CONSULTORIOJ...
# 1            3930874  UNIVERSIDAD  FACULTAD DE DERECHO  CONSULTORIOJ...
# 2             414466  UNIVERSIDAD  FACULTAD DE DERECHO  CONSULTORIOJ...
# 3             441614  UNIVERSIDAD  FACULTAD DE DERECHO  CONSULTORIOJ...
# 4              39309  UNIVERSIDAD  FACULTAD DE DERECHO  CONSULTORIOJ...
# ...              ...                                                ...
# 3737187      6998858                            Conciliación en Equidad
# 3737188      6998861                            Conciliación en Equidad
# 3737189      6998863                            Conciliación en Equidad
# 3737190      6998867                            Conciliación en Equidad
# 3737191      6998868                            Conciliación en Equidad
#
#                       NomCasaJusticia               FechaSolicitud
# 0             CASA DE JUSTICIA CAJICA                   10/21/2019
# 1             CASA DE JUSTICIA CAJICA      2019-05-08T00:00:00.000
# 2             CASA DE JUSTICIA CAJICA                   09/16/2019
# 3             CASA DE JUSTICIA CAJICA                   09/30/2019
# 4             CASA DE JUSTICIA CAJICA      2019-05-08T00:00:00.000
# ...                               ...                          ...
# 3737187  CASA DE JUSTICIA SANTA MARTA  2024-09-30 18:32:12.7903092
# 3737188  CASA DE JUSTICIA SANTA MARTA  2024-09-30 18:38:10.1276910
# 3737189  CASA DE JUSTICIA SANTA MARTA  2024-09-30 18:59:42.8782731
# 3737190  CASA DE JUSTICIA SANTA MARTA  2024-09-30 20:03:26.6302227
# 3737191  CASA DE JUSTICIA SANTA MARTA  2024-09-30 20:06:36.7694749
#
# [3737192 rows x 4 columns]

# %% [markdown]
# ### Include departments and municipality

# %%
df = pd.merge(data1, data2, left_on="NomCasaJusticia", right_on="CASA DE JUSTICIA")
del df["CASA DE JUSTICIA"]
df
# Out:
#          IdSolicitud                                         NomEntidad  \
# 0             481137  UNIVERSIDAD  FACULTAD DE DERECHO  CONSULTORIOJ...
# 1            3930874  UNIVERSIDAD  FACULTAD DE DERECHO  CONSULTORIOJ...
# 2             414466  UNIVERSIDAD  FACULTAD DE DERECHO  CONSULTORIOJ...
# 3             441614  UNIVERSIDAD  FACULTAD DE DERECHO  CONSULTORIOJ...
# 4              39309  UNIVERSIDAD  FACULTAD DE DERECHO  CONSULTORIOJ...
# ...              ...                                                ...
# 3607567      6998858                            Conciliación en Equidad
# 3607568      6998861                            Conciliación en Equidad
# 3607569      6998863                            Conciliación en Equidad
# 3607570      6998867                            Conciliación en Equidad
# 3607571      6998868                            Conciliación en Equidad
#
#                       NomCasaJusticia               FechaSolicitud  \
# 0             CASA DE JUSTICIA CAJICA                   10/21/2019
# 1             CASA DE JUSTICIA CAJICA      2019-05-08T00:00:00.000
# 2             CASA DE JUSTICIA CAJICA                   09/16/2019
# 3             CASA DE JUSTICIA CAJICA                   09/30/2019
# 4             CASA DE JUSTICIA CAJICA      2019-05-08T00:00:00.000
# ...                               ...                          ...
# 3607567  CASA DE JUSTICIA SANTA MARTA  2024-09-30 18:32:12.7903092
# 3607568  CASA DE JUSTICIA SANTA MARTA  2024-09-30 18:38:10.1276910
# 3607569  CASA DE JUSTICIA SANTA MARTA  2024-09-30 18:59:42.8782731
# 3607570  CASA DE JUSTICIA SANTA MARTA  2024-09-30 20:03:26.6302227
# 3607571  CASA DE JUSTICIA SANTA MARTA  2024-09-30 20:06:36.7694749
#
#          DEPARTAMENTO    MUNICIPIO
# 0        CUNDINAMARCA       CAJICA
# 1        CUNDINAMARCA       CAJICA
# 2        CUNDINAMARCA       CAJICA
# 3        CUNDINAMARCA       CAJICA
# 4        CUNDINAMARCA       CAJICA
# ...               ...          ...
# 3607567     MAGDALENA  SANTA MARTA
# 3607568     MAGDALENA  SANTA MARTA
# 3607569     MAGDALENA  SANTA MARTA
# 3607570     MAGDALENA  SANTA MARTA
# 3607571     MAGDALENA  SANTA MARTA
#
# [3607572 rows x 6 columns]

# %%
df.isna().sum()
# Out:
# IdSolicitud           0
# NomEntidad         1310
# NomCasaJusticia       0
# FechaSolicitud        0
# DEPARTAMENTO          0
# MUNICIPIO             0
# dtype: int64

# %% [markdown]
# ### Include longitude and latitude
#
# Temporarily is not being used, because some ideas changed so this has to be reformed

# %%
def get_coordinates(place_name: str) -> tuple[float, float] | None:
    url = 'https://nominatim.openstreetmap.org/search'
    params = {
        'q': str(place_name),      
        'format': 'json',      
        'addressdetails': 1,   
        'limit': 1             
    }

    headers = {
        'User-Agent': 'TuApp/1.0 (tucorreo@dominio.com)'
    }

    response = requests.get(url, params=params, headers=headers)
    if response.status_code != 200:
        return None

    data1 = response.json()
    if not data1:
        return None
    
    if data1[0]['address']['country_code'] != 'co':
        return None

    lat = data1[0]['lat']
    lon = data1[0]['lon']
    return lat, lon

# %%
df = data1.copy()
row = data1['NomCasaJusticia'].unique()

for index, place in enumerate(row):
    clear_output(wait=True)

    display(f'{index + 1} / {len(row)}: {place}')

    response = get_coordinates(place)
    if not response:
        df = df.drop(data1[data1['NomCasaJusticia'] == place].index)
        continue

    df.loc[df['NomCasaJusticia'] == place, ['lat', 'lon']] = response

df

# %%
df.isna().sum()
# Out:
# IdSolicitud          0
# NomEntidad         413
# NomCasaJusticia      0
# FechaSolicitud       0
# lat                  0
# lon                  0
# municipality         0
# department           0
# dtype: int64

# %% [markdown]
# ## Fix date format

# %%
df['FechaSolicitud']
# Out:
# 0                           10/21/2019
# 1              2019-05-08T00:00:00.000
# 2                           09/16/2019
# 3                           09/30/2019
# 4              2019-05-08T00:00:00.000
#                       ...
# 3607567    2024-09-30 18:32:12.7903092
# 3607568    2024-09-30 18:38:10.1276910
# 3607569    2024-09-30 18:59:42.8782731
# 3607570    2024-09-30 20:03:26.6302227
# 3607571    2024-09-30 20:06:36.7694749
# Name: FechaSolicitud, Length: 3607572, dtype: object

# %%
def date_convert(fecha):
    formatos = [
        "%m/%d/%Y",              # formato MM/DD/YYYY
        "%Y-%m-%dT%H:%M:%S.%f",  # formato ISO con milisegundos
        "%Y-%m-%d %H:%M:%S.%f",  # formato con milisegundos y espacios
        "%Y-%m-%d",              # formato YYYY-MM-DD
        "%m/%d/%Y %H:%M:%S",     # formato MM/DD/YYYY HH:MM:SS
    ]
    
    for fmt in formatos:
        try:
            return pd.to_datetime(fecha, format=fmt)
        except ValueError:
            continue
    return pd.NaT

# %%
df['FechaSolicitud'] = df['FechaSolicitud'].apply(date_convert)
df['FechaSolicitud'] = df['FechaSolicitud'].dt.strftime('%Y-%m-%d')
invalid_dates = df['FechaSolicitud'].isna().sum()
print(f"Fechas no válidas encontradas después del intento de conversión: {invalid_dates}")
# Out:
# Fechas no válidas encontradas después del intento de conversión: 0

# %%
df
# Out:
#          IdSolicitud                                         NomEntidad  \
# 0             481137  UNIVERSIDAD  FACULTAD DE DERECHO  CONSULTORIOJ...
# 1            3930874  UNIVERSIDAD  FACULTAD DE DERECHO  CONSULTORIOJ...
# 2             414466  UNIVERSIDAD  FACULTAD DE DERECHO  CONSULTORIOJ...
# 3             441614  UNIVERSIDAD  FACULTAD DE DERECHO  CONSULTORIOJ...
# 4              39309  UNIVERSIDAD  FACULTAD DE DERECHO  CONSULTORIOJ...
# ...              ...                                                ...
# 3607567      6998858                            Conciliación en Equidad
# 3607568      6998861                            Conciliación en Equidad
# 3607569      6998863                            Conciliación en Equidad
# 3607570      6998867                            Conciliación en Equidad
# 3607571      6998868                            Conciliación en Equidad
#
#                       NomCasaJusticia FechaSolicitud  DEPARTAMENTO  \
# 0             CASA DE JUSTICIA CAJICA     2019-10-21  CUNDINAMARCA
# 1             CASA DE JUSTICIA CAJICA     2019-05-08  CUNDINAMARCA
# 2             CASA DE JUSTICIA CAJICA     2019-09-16  CUNDINAMARCA
# 3             CASA DE JUSTICIA CAJICA     2019-09-30  CUNDINAMARCA
# 4             CASA DE JUSTICIA CAJICA     2019-05-08  CUNDINAMARCA
# ...                               ...            ...           ...
# 3607567  CASA DE JUSTICIA SANTA MARTA     2024-09-30     MAGDALENA
# 3607568  CASA DE JUSTICIA SANTA MARTA     2024-09-30     MAGDALENA
# 3607569  CASA DE JUSTICIA SANTA MARTA     2024-09-30     MAGDALENA
# 3607570  CASA DE JUSTICIA SANTA MARTA     2024-09-30     MAGDALENA
# 3607571  CASA DE JUSTICIA SANTA MARTA     2024-09-30     MAGDALENA
#
#            MUNICIPIO
# 0             CAJICA
# 1             CAJICA
# 2             CAJICA
# 3             CAJICA
# 4             CAJICA
# ...              ...
# 3607567  SANTA MARTA
# 3607568  SANTA MARTA
# 3607569  SANTA MARTA
# 3607570  SANTA MARTA
# 3607571  SANTA MARTA
#
# [3607572 rows x 6 columns]

# %% [markdown]
# ## Craft some extras features

# %%
days = []
months = []
years = []
day_of_week = []

for x in df["FechaSolicitud"].tolist():
    x = datetime.strptime(x, "%Y-%m-%d").date()
    
    days.append(x.day)
    months.append(x.month)
    years.append(x.year)
    day_of_week.append(x.isoweekday())

# %%
df["days"] = days
df["months"] = months
df["years"] = years
df["day_of_week"] = day_of_week

# %%
df
# Out:
#          IdSolicitud                                         NomEntidad  \
# 0             481137  UNIVERSIDAD  FACULTAD DE DERECHO  CONSULTORIOJ...
# 1            3930874  UNIVERSIDAD  FACULTAD DE DERECHO  CONSULTORIOJ...
# 2             414466  UNIVERSIDAD  FACULTAD DE DERECHO  CONSULTORIOJ...
# 3             441614  UNIVERSIDAD  FACULTAD DE DERECHO  CONSULTORIOJ...
# 4              39309  UNIVERSIDAD  FACULTAD DE DERECHO  CONSULTORIOJ...
# ...              ...                                                ...
# 3607567      6998858                            Conciliación en Equidad
# 3607568      6998861                            Conciliación en Equidad
# 3607569      6998863                            Conciliación en Equidad
# 3607570      6998867                            Conciliación en Equidad
# 3607571      6998868                            Conciliación en Equidad
#
#                       NomCasaJusticia FechaSolicitud  DEPARTAMENTO  \
# 0             CASA DE JUSTICIA CAJICA     2019-10-21  CUNDINAMARCA
# 1             CASA DE JUSTICIA CAJICA     2019-05-08  CUNDINAMARCA
# 2             CASA DE JUSTICIA CAJICA     2019-09-16  CUNDINAMARCA
# 3             CASA DE JUSTICIA CAJICA     2019-09-30  CUNDINAMARCA
# 4             CASA DE JUSTICIA CAJICA     2019-05-08  CUNDINAMARCA
# ...                               ...            ...           ...
# 3607567  CASA DE JUSTICIA SANTA MARTA     2024-09-30     MAGDALENA
# 3607568  CASA DE JUSTICIA SANTA MARTA     2024-09-30     MAGDALENA
# 3607569  CASA DE JUSTICIA SANTA MARTA     2024-09-30     MAGDALENA
# 3607570  CASA DE JUSTICIA SANTA MARTA     2024-09-30     MAGDALENA
# 3607571  CASA DE JUSTICIA SANTA MARTA     2024-09-30     MAGDALENA
#
#            MUNICIPIO  days  months  years  day_of_week
# 0             CAJICA    21      10   2019            1
# 1             CAJICA     8       5   2019            3
# 2             CAJICA    16       9   2019            1
# 3             CAJICA    30       9   2019            1
# 4             CAJICA     8       5   2019            3
# ...              ...   ...     ...    ...          ...
# 3607567  SANTA MARTA    30       9   2024            1
# 3607568  SANTA MARTA    30       9   2024            1
# 3607569  SANTA MARTA    30       9   2024            1
# 3607570  SANTA MARTA    30       9   2024            1
# 3607571  SANTA MARTA    30       9   2024            1
#
# [3607572 rows x 10 columns]

# %%
df.to_csv("./processed/Procesos_casas_de_justicia.csv")
